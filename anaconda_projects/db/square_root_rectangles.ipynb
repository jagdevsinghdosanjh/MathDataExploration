# %% [markdown]
# # Square Root Rectangles

# %%
import numpy as np
import matplotlib.pyplot as plt

sqrt_values = [np.sqrt(2), np.sqrt(3),np.sqrt(4),np.sqrt(5),np.sqrt(6)]
fig, ax = plt.subplots(figsize=(6, 4))

# Draw rectangles
for i, sqrt_val in enumerate(sqrt_values):
    rect = plt.Rectangle((i, 0), 1, sqrt_val, edgecolor='green', facecolor='none', lw=2)
    ax.add_patch(rect)
    plt.text(i + 0.4, sqrt_val / 2, f"√{i+2}", fontsize=12)

plt.xlim(-0.125, len(sqrt_values) + 0.125)
plt.ylim(0, max(sqrt_values) + 0.125)
plt.title("Square Root Rectangles")
plt.grid()
plt.show()
